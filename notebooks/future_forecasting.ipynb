# %% [markdown]
# # Forecast Future Market Trends

# %% [markdown]
# Based on the best models trained, will forcast the next 6-12 months of Tesla's price
# - analyze tesla's trend
# - analyze risk
# - analyze volatility
# - analyze market oportunity

# %% [markdown]
# First, import required libraries and script modules

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os, sys
# Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))

# Set max rows and columns to display
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# Configure logging
from logger import SetupLogger
# Assuming this class is defined in scripts/
from data_preprocessing import DataPreprocessor
from future_forecasting import ModelForecaster
logger = SetupLogger(log_file='../logs/notebooks.log').get_logger()

# Set default figure size for all plots
plt.rcParams['figure.figsize'] = (14, 7)
# Out:
# 2024-11-17 11:03:37.034481: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-17 11:03:39.268405: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-17 11:03:39.303520: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731859419.362507   55152 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731859419.595943   55152 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# **Loading the recent Tesla's Dataset**

# %%
# Initialize class instances
path = '../data/'
processor = DataPreprocessor(data_dir = path, logger=logger)

# Load the data
tsla_data = processor.load_data('TSLA')

# %% [markdown]
# Model Forcasting

# %%
# Initialize forecaster
forecaster = ModelForecaster(tsla_data, '../data/tsla_forecast_12_months.csv', logger=logger)

# Plot forecasts
forecaster.plot_forecast()

# %%
# Analyze forecasts
result = forecaster.analyze_forecast()
result
# Out:
#   Volatility and Risk: Potential increase in volatility, which could lead to market risk.
#   Market Opportunities/Risks: Opportunity with high risk due to increased volatility.
#            Trend Trend_Magnitude Volatility Volatility_Level  Max_Price  \
# forecast  upward         1.05165  22.847456             High  264.71103
#
#          Min_Price Price_Range
# forecast  183.0386    81.67243
